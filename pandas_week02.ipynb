# %% [markdown]
# # Python数据分析基础_week02

# %%
import pandas as pd

# %%
# %%html
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 45%;
#     height: auto;
#     float: right;
# }
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>
# Out:
# <style>
# /* 本电子讲义使用之CSS */
# div.code_cell {
#     background-color: #e5f1fe;
# }
# div.cell.selected {
#     background-color: #effee2;
#     font-size: 2rem;
#     line-height: 2.4rem;
# }
# div.cell.selected .rendered_html table {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html pre code {
#     background-color: #C4E4ff;
#     padding: 2px 25px;
# }
# .rendered_html pre {
#     background-color: #99c9ff;
# }
# div.code_cell .CodeMirror {
#     font-size: 2rem !important;
#     line-height: 2.4rem !important;
# }
# .rendered_html img, .rendered_html svg {
#     max-width: 45%;
#     height: auto;
#     float: right;
# }
# /* Gradient transparent - color - transparent */
# hr {
#     border: 0;
#     border-bottom: 1px dashed #ccc;
# }
# .emoticon{
#     font-size: 5rem;
#     line-height: 4.4rem;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# ![01_table_dataframe.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/01_table_dataframe.svg)
#
#
#
# * [熊猫处理什么样的数据？](#熊猫处理什么样的数据？)
#
# > <mark>框框框</mark>，探索，清理和处理数据在Pandas中，数据表称为DataFrame，数据科学家**变数variables**通常放(竖着的列)column，**观察observations**通常放(横着的行)row
#
# <br/><br/><br/>
#
# -----
#
# ![02_io_readwrite.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/02_io_readwrite.svg)
#
# * [如何读写表格数据？](#如何读写表格数据？)
#
# > <mark>读读读，写写写</mark>，数据科学家不想浪费时间编程去处理不同数据格式，所以pandas集成了常用的现成的文件格式或数据源（csv，excel，sql，json，parquet等）...
#
# -----
#
# ![03_subset_columns_rows.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/03_subset_columns_rows.svg)
#
# * [如何选择表格的子集？](#如何选择表格的子集？)
#
# > <mark>切切切</mark>，**切片** (英文叫slice) 是数据科学家找突破点的重要工具，是她们的数据解剖刀...
#
# -----
#
# ![04_plot_overview.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/04_plot_overview.svg)
#
# * [如何在熊猫中绘图？](#如何在熊猫中绘图？)
#
# > <mark>绘绘绘</mark>，**绘图** ( 数据框.plot() ) 是数据科学家**以数据框为中心**的代码实践，减少以图表类型为开头的编程思维来作图
#
# -----
#
# ![05_newcolumn_2.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/05_newcolumn_2.svg)
#
# * [如何从现有列创建派生新列？](#如何从现有列创建派生新列？)
#
# > <mark>列列列</mark>，派生新列意谓着变数variables的进一部转换，是数据科学家按步就班做ETL的过程，新派生列就是**变数variables**的转换
#
# -----
#
# ![06_groupby.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/06_groupby.svg)
#
# * [如何计算汇总描述性统计信息？](#如何计算汇总描述性统计信息？)
#
# > <mark>算算算</mark>，描述性统计竟然代码可以这麽容易....，但难的仍是在数据科学家的数据定义及解释上
#
# <div class="emoticon">😃😄😁</div>
#
# -----

# %% [markdown]
# ## 熊猫处理什么样的数据？
#
# > <mark>框框框</mark>，探索，清理和处理数据在Pandas中，数据表称为DataFrame**
#
# **数据框是众多变数的观察序列**
#
# 对数据科学家来说:
#
# * 竖着的列column通常放**变数variables**
# * 横着的行row通常放**观察observations**
# ![01_table_dataframe.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/01_table_dataframe.svg)
#
# 对数据及信息管理人员来说:
# * 表格数据（例如存储在电子表格或数据库中的数据）是很常见的，最主流的数据结构和查询语言是SQL
# * 树状文本数据（例如HTML, XML, JSON数据）是很常见的，HTML/XML最主流的查询语言是xpath
#
#
# -----

# %% [markdown]
# ### 框框框的代码片语
# **要注意标点及缩进**
#
# ```python
# 框框 = pd.DataFrame ( {
#         "变数X": ["观察X1", "观察X2", "观察X3", "观察X4"],
#         "变数Y": ["观察Y1", "观察Y2", "观察Y3", "观察Y4"],
#         "变数Z": ["观察Z1", "观察Z2", "观察Z3", "观察Z4"],
#       } )```
#
#
#
# * pd.DataFrame 的主流参数是字典
# * 该字典的键keys是由变数构成，相当於表格中一行行的标题
# * 该字典的值values是由观察的列表构成，相当於表格中一行行的数据
# * 表格真的要是表格, 该字典的每个观察的列表数量必需齐一
#
# [小贴士] 最后一个逗点可有可无(为什麽?)，在pandas情境下最好留(为什麽?)
#
# **保留逗号可以让格式更加整齐，避免出错**

# %% [markdown]
#
# #### 练习A1-框框框的课堂建构

# %%
# A1 dict
# 先弄字典, 再弄 框框 的写法片语
字典 = {
        "变数A": ["观察A1", "观察A2", "观察A3", "观察A4"],
        "变数B": ["观察B1", "观察B2", "观察B3", "观察B4"],
        "变数C": ["观察C1", "观察C2", "观察C3", "观察C4"],
        "变数D": ["观察D1", "观察D2", "观察D3", "观察D4"],
        "变数E": ["观察E1", "观察E2", "观察E3", "观察E4"],
       }

框框 = pd.DataFrame ( 字典 )
display (框框)
# Out:
#     变数A   变数B   变数C   变数D   变数E
# 0  观察A1  观察B1  观察C1  观察D1  观察E1
# 1  观察A2  观察B2  观察C2  观察D2  观察E2
# 2  观察A3  观察B3  观察C3  观察D3  观察E3
# 3  观察A4  观察B4  观察C4  观察D4  观察E4

# %%
# A1 print
# 在ipynb用 print比较不上看，因为是文字text输出为主
print (框框)
# Out:
#     变数A   变数B   变数C   变数D   变数E
# 0  观察A1  观察B1  观察C1  观察D1  观察E1
# 1  观察A2  观察B2  观察C2  观察D2  观察E2
# 2  观察A3  观察B3  观察C3  观察D3  观察E3
# 3  观察A4  观察B4  观察C4  观察D4  观察E4

# %%
# A1 display
# 在ipynb可用 display 比较上看

from IPython.display import display, HTML
# 從 IPython.display 模塊 導入使用 display和HTML
display (框框)
# Out:
#     变数A   变数B   变数C   变数D   变数E
# 0  观察A1  观察B1  观察C1  观察D1  观察E1
# 1  观察A2  观察B2  观察C2  观察D2  观察E2
# 2  观察A3  观察B3  观察C3  观察D3  观察E3
# 3  观察A4  观察B4  观察C4  观察D4  观察E4

# %% [markdown]
# #### 练习A2-**框框框**(DataFrame)的取变数成 **系列** (Series)

# %%
# A2 Series
# first slice
框框 ["变数A"]  
# [] 像字典取值, 改值从列表升级为有**索引的序列series**
# "0,1,2,3"→索引
# dtype：数据的形态
# object 对象/物件
# Out:
# 0    观察A1
# 1    观察A2
# 2    观察A3
# 3    观察A4
# Name: 变数A, dtype: object

# %%
# A2 Series values
框框 ["变数A"].values # 值
# array 阵列
# Out:
# array(['观察A1', '观察A2', '观察A3', '观察A4'], dtype=object)

# %%
# A2 Series index
框框 ["变数A"].index # 索引
# RangeIndex 跟 range（0,4）相似
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
list(框框 ["变数A"].index)
# Out:
# [0, 1, 2, 3]

# %%
# A2 DataFrame .loc[]
# 用 .loc[] 取列, 相当於所有变数的某一次观察
框框.loc[3]   # loc = location  row
# Out:
# 变数A    观察A4
# 变数B    观察B4
# 变数C    观察C4
# 变数D    观察D4
# 变数E    观察E4
# Name: 3, dtype: object

# %%
# A2 Series to_list()
# 降阶打击, 变列表的方法
print ( 框框 ["变数A"].to_list() )    
print ( list(框框 ["变数A"]) )
print ( list(框框 ["变数A"].values) )
print ( list(框框 ["变数A"].index) )

# 区分读/写代码: 
# 你可以挑一个你比较常用的"说法", 
# 但你看到别人不同的说法时, 你需要知道是同一件事
# Out:
# ['观察A1', '观察A2', '观察A3', '观察A4']
# ['观察A1', '观察A2', '观察A3', '观察A4']
# ['观察A1', '观察A2', '观察A3', '观察A4']
# [0, 1, 2, 3]

# %% [markdown]
# ![01_table_dataframe.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/01_table_dataframe.svg)
# ### 框框框的小结
# 以下为廖老师示范，其它小结需要自己做小结
# 1. 对数据科学来说，表格数据的习惯是变数variables与观察observations
# 2. 在Pandas框框框的建构来说，就是可以把变数和观察用索引的方式使用
# 3. 框框框的字典取的是某个变数所有观察, 用.loc[]取數次观察的所有变数
#   * .loc[] 取  观察, 行 column
#   * [""] 取  变数, 列 row
#
# <div class="emoticon">😃😄😁</div>
#
# -----
# -----

# %% [markdown]
# ![02_io_readwrite.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/02_io_readwrite.svg)
# ## 如何读写表格数据？
# 读读读，写写写，数据科学家不想浪费时间编程去处理不同数据格式，所以pandas集成了常用的现成的文件格式或数据源（csv，excel，sql，json，parquet等）...

# %% [markdown]
# ### 读读读的代码片语
# 读读读的代码片语 (code snippets)，新手请认真记忆，**注意标点及缩进**
#
# ```python
#
# 读到csv = pd.read_csv("路径档案名", encoding="utf8")
# 读到tsv = pd.read_csv("路径档案名", encoding="utf8", sep="\t")
# 读到excel = pd.read_excel("路径档案名", sheet_name="分页名称")
# ```
#
# 代码片语说明
#
#
#
# * pd.read_csv
# * pd.read_excel
# * df.head()
#
# -----

# %%
# B1 20春_pandas_week02_hurun_unicorn.tsv
df = pd.read_csv("20春_pandas_week02_hurun_unicorn.tsv", encoding="utf8", sep="\t")
df.head()
# Out:
#    排名       企业名称   Company Name  估值（亿人民币）  国家   城市     行业  \
# 0   1       蚂蚁金服  Ant Financial     10000  中国   杭州   金融科技
# 1   2       字节跳动      Bytedance      5000  中国   北京  媒体和娱乐
# 2   3       滴滴出行   Didi Chuxing      3600  中国   北京   共享经济
# 3   4      Infor          Infor      3500  美国   纽约    云计算
# 4   5  JUUL Labs      JUUL Labs      3400  美国  旧金山    消费品
#
#                                              掌门人/创始人  成立年份  \
# 0                                                井贤栋  2014
# 1                                                张一鸣  2012
# 2                                                 程维  2012
# 3                                        Jim Schaper  2002
# 4  Adam Bowen, James Monsees, Kevin Burns, Tim Da...  2015
#
#                                               部分投资机构
# 0                                     春华资本、中投海外、红杉资本
# 1                                红杉资本、海纳亚洲、纪源资本、启明创投
# 2                             腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本
# 3       Golden Gate Capital, Koch Equity Development
# 4  M13, Timothy Davis, Evolution VC Partners, Tig...

# %%
# B2 20春_pandas_week02_hurun_unicorn_more.csv
df = pd.read_csv("20春_pandas_week02_hurun_unicorn_more.csv", encoding="utf8", sep="\t")
df.head()
# Out:
#    排名  企业名称   Company Name  估值（亿人民币）  国家  城市     行业 掌门人/创始人  成立年份  \
# 0   1  蚂蚁金服  Ant Financial     10000  中国  杭州   金融科技     井贤栋  2014
# 1   2  字节跳动      Bytedance      5000  中国  北京  媒体和娱乐     张一鸣  2012
# 2   3  滴滴出行   Didi Chuxing      3600  中国  北京   共享经济      程维  2012
# 3   6   陆金所          Lufax      2700  中国  上海   金融科技     计葵生  2011
# 4  11  微众银行         WeBank      1500  中国  深圳   金融科技      顾敏  2014
#
#                    部分投资机构   region
# 0          春华资本、中投海外、红杉资本  环杭州湾大湾区
# 1     红杉资本、海纳亚洲、纪源资本、启明创投    渤海大湾区
# 2  腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本    渤海大湾区
# 3     摩根士丹利、中银集团、国泰君安（香港）  环杭州湾大湾区
# 4             腾讯、华平投资、淡马锡   粤港澳大湾区

# %%
# B3 20春_pandas_week02_hurun_unicorn.xlsx
df = pd.read_excel("20春_pandas_week02_hurun_unicorn.xlsx", encoding="utf8", sheet_name="独角兽")
df.head()
# Out:
#    排名       企业名称   Company Name  估值（亿人民币）  国家   城市     行业  \
# 0   1       蚂蚁金服  Ant Financial     10000  中国   杭州   金融科技
# 1   2       字节跳动      Bytedance      5000  中国   北京  媒体和娱乐
# 2   3       滴滴出行   Didi Chuxing      3600  中国   北京   共享经济
# 3   4      Infor          Infor      3500  美国   纽约    云计算
# 4   5  JUUL Labs      JUUL Labs      3400  美国  旧金山    消费品
#
#                                              掌门人/创始人  成立年份  \
# 0                                                井贤栋  2014
# 1                                                张一鸣  2012
# 2                                                 程维  2012
# 3                                        Jim Schaper  2002
# 4  Adam Bowen, James Monsees, Kevin Burns, Tim Da...  2015
#
#                                               部分投资机构
# 0                                     春华资本、中投海外、红杉资本
# 1                                红杉资本、海纳亚洲、纪源资本、启明创投
# 2                             腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本
# 3       Golden Gate Capital, Koch Equity Development
# 4  M13, Timothy Davis, Evolution VC Partners, Tig...

# %%
df.info()
# info：读取信息 可以读出数据框的所有变数的信息 下面每个变数都有494个观察
# int64 整数
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 10 columns):
# 排名              494 non-null int64
# 企业名称            494 non-null object
# Company Name    494 non-null object
# 估值（亿人民币）        494 non-null int64
# 国家              494 non-null object
# 城市              494 non-null object
# 行业              494 non-null object
# 掌门人/创始人         494 non-null object
# 成立年份            494 non-null int64
# 部分投资机构          494 non-null object
# dtypes: int64(3), object(7)
# memory usage: 38.7+ KB

# %%
# shape 是一个常量 横跟宽 
df.shape
# Out:
# (494, 10)

# %%
# 有多少观察
df.shape[0]
# 与 print (len(df.index)) 相同结果
# Out:
# 494

# %%
# 有多少变数
df.shape[1]
# 与 print (len(df.columns)) 相同结果
# Out:
# 10

# %%
df.describe().to_dict()
# Out:
# {'排名': {'count': 494.0,
#   'mean': 180.97773279352228,
#   'std': 91.07319075981641,
#   'min': 1.0,
#   '25%': 84.0,
#   '50%': 224.0,
#   '75%': 264.0,
#   'max': 264.0},
#  '估值（亿人民币）': {'count': 494.0,
#   'mean': 238.80566801619435,
#   'std': 623.1585372633193,
#   'min': 70.0,
#   '25%': 70.0,
#   '50%': 100.0,
#   '75%': 200.0,
#   'max': 10000.0},
#  '成立年份': {'count': 494.0,
#   'mean': 2011.2348178137652,
#   'std': 3.7924771092178786,
#   'min': 2000.0,
#   '25%': 2009.0,
#   '50%': 2012.0,
#   '75%': 2014.0,
#   'max': 2019.0}}

# %%
df.describe(include="all")
# Out:
#                 排名 企业名称 Company Name      估值（亿人民币）   国家   城市    行业 掌门人/创始人  \
# count   494.000000  494          494    494.000000  494  494   494     494
# unique         NaN  494          494           NaN   24  120    25     485
# top            NaN  准时达    Linklogis           NaN   中国   北京  电子商务      张勇
# freq           NaN    1            1           NaN  206   81    68       3
# mean    180.977733  NaN          NaN    238.805668  NaN  NaN   NaN     NaN
# std      91.073191  NaN          NaN    623.158537  NaN  NaN   NaN     NaN
# min       1.000000  NaN          NaN     70.000000  NaN  NaN   NaN     NaN
# 25%      84.000000  NaN          NaN     70.000000  NaN  NaN   NaN     NaN
# 50%     224.000000  NaN          NaN    100.000000  NaN  NaN   NaN     NaN
# 75%     264.000000  NaN          NaN    200.000000  NaN  NaN   NaN     NaN
# max     264.000000  NaN          NaN  10000.000000  NaN  NaN   NaN     NaN
#
#                成立年份 部分投资机构
# count    494.000000    494
# unique          NaN    489
# top             NaN    未透露
# freq            NaN      3
# mean    2011.234818    NaN
# std        3.792477    NaN
# min     2000.000000    NaN
# 25%     2009.000000    NaN
# 50%     2012.000000    NaN
# 75%     2014.000000    NaN
# max     2019.000000    NaN

# %%
# B8 df.to_markdown()
# B9 df.to_html()
# B10 df.to_json()

# %%
df.describe()
# Out:
#                排名      估值（亿人民币）         成立年份
# count  494.000000    494.000000   494.000000
# mean   180.977733    238.805668  2011.234818
# std     91.073191    623.158537     3.792477
# min      1.000000     70.000000  2000.000000
# 25%     84.000000     70.000000  2009.000000
# 50%    224.000000    100.000000  2012.000000
# 75%    264.000000    200.000000  2014.000000
# max    264.000000  10000.000000  2019.000000

# %%
df.describe()["排名"]
# Out:
# count    494.000000
# mean     180.977733
# std       91.073191
# min        1.000000
# 25%       84.000000
# 50%      224.000000
# 75%      264.000000
# max      264.000000
# Name: 排名, dtype: float64

# %%
df.describe().loc['count']
# Out:
# 排名          494.0
# 估值（亿人民币）    494.0
# 成立年份        494.0
# Name: count, dtype: float64

# %%
df.describe().to_dict()
# Out:
# {'排名': {'count': 494.0,
#   'mean': 180.97773279352228,
#   'std': 91.07319075981641,
#   'min': 1.0,
#   '25%': 84.0,
#   '50%': 224.0,
#   '75%': 264.0,
#   'max': 264.0},
#  '估值（亿人民币）': {'count': 494.0,
#   'mean': 238.80566801619435,
#   'std': 623.1585372633193,
#   'min': 70.0,
#   '25%': 70.0,
#   '50%': 100.0,
#   '75%': 200.0,
#   'max': 10000.0},
#  '成立年份': {'count': 494.0,
#   'mean': 2011.2348178137652,
#   'std': 3.7924771092178786,
#   'min': 2000.0,
#   '25%': 2009.0,
#   '50%': 2012.0,
#   '75%': 2014.0,
#   'max': 2019.0}}

# %% [markdown]
# ![02_io_readwrite.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/02_io_readwrite.svg)
# ### 读读读的小结
# - df.head()-- head括号里面没写数字的话一般默认前五名括号里面写几就会显示前几名
# - df.info()-- 读取信息 可以读出数据框的所有变数的信息
# - df.shape --shape 是一个常量 变数和观察
# - df.describe(include="all") -- 抽取部分信息
#
#
# <div class="emoticon">😃😄😁</div>
#
# -----
# -----

# %% [markdown]
# ![03_subset_columns_rows.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/03_subset_columns_rows.svg)
# ## 如何选择表格的子集？
#
# 切切切，**切片** (英文叫slice) 是数据科学家找突破点的重要工具，是她们的数据解剖刀...
#
# 参考 CheatSheet
# * Subset Observations (Rows) 列
# * Subset Variables (Columns) 行

# %% [markdown]
# ### 切切切的代码片语
# 切切切的代码片语 (code snippets)，新手请认真记忆，**注意标点及缩进**
#
#
# ####  列子集
# ```python
#
# df.loc()
# df.iloc()
# df.set_index()
# df.head(n)
# df.tail(n)
# df.nlargest(n, '变量')
# df.nsmallest(n, '变量')
# df[df.估值（亿人民币）> 10]
# ```
#
# #### 行子集
# ```python
#
# #  行子集
# df[['变量X','变量Y','变量Z']]
# df[['变量X']]
# df['变量X']
# ```
#
# #### 列+行子集
# ```python
#
# #  行子集
# df.loc[:,['变量X':'变量Z']]    # 注意中括号里的: 和 ,的使用
# df.iloc[:,[1,2,5]]
# df.loc[df['变量X']>10, ['变量X','变量Z'] ]
# ```
#
# 子集代码片语说明(你来做笔记)
# * 列子集
# * 行子集
#
# -----

# %%
df.loc[[0,2],["排名","企业名称","估值（亿人民币）"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 2
# Data columns (total 3 columns):
# 排名          2 non-null int64
# 企业名称        2 non-null object
# 估值（亿人民币）    2 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 64.0+ bytes

# %%
df[df["估值（亿人民币）"]> 3500]
# Out:
#    排名  企业名称   Company Name  估值（亿人民币）  国家  城市     行业 掌门人/创始人  成立年份  \
# 0   1  蚂蚁金服  Ant Financial     10000  中国  杭州   金融科技     井贤栋  2014
# 1   2  字节跳动      Bytedance      5000  中国  北京  媒体和娱乐     张一鸣  2012
# 2   3  滴滴出行   Didi Chuxing      3600  中国  北京   共享经济      程维  2012
#
#                    部分投资机构
# 0          春华资本、中投海外、红杉资本
# 1     红杉资本、海纳亚洲、纪源资本、启明创投
# 2  腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本

# %%
df.nlargest(3, '估值（亿人民币）')
# Out:
#    排名  企业名称   Company Name  估值（亿人民币）  国家  城市     行业 掌门人/创始人  成立年份  \
# 0   1  蚂蚁金服  Ant Financial     10000  中国  杭州   金融科技     井贤栋  2014
# 1   2  字节跳动      Bytedance      5000  中国  北京  媒体和娱乐     张一鸣  2012
# 2   3  滴滴出行   Didi Chuxing      3600  中国  北京   共享经济      程维  2012
#
#                    部分投资机构
# 0          春华资本、中投海外、红杉资本
# 1     红杉资本、海纳亚洲、纪源资本、启明创投
# 2  腾讯、阿里巴巴、红杉资本、经纬中国、纪源资本

# %%
df.nsmallest(3, '估值（亿人民币）')
# Out:
#       排名          企业名称  Company Name  估值（亿人民币）  国家    城市    行业  \
# 263  264          百融金服     100credit        70  中国    北京  金融科技
# 264  264  10X Genomics  10X Genomics        70  美国  普莱森顿  生命科学
# 265  264          一起作业       17zuoye        70  中国    上海  教育科技
#
#                         掌门人/创始人  成立年份  \
# 263                         张韶峰  2014
# 264  Ben Hindson, Serge Saxonov  2012
# 265                          刘畅  2007
#
#                                                 部分投资机构
# 263                            中国国新、中金前海、红杉资本、IDG、高瓴资本
# 264  Foresite Capital, Fidelity Management and Rese...
# 265                                     真格基金、顺为资本、老虎基金

# %%
df['企业名称']
# Out:
# 0                       蚂蚁金服
# 1                       字节跳动
# 2                       滴滴出行
# 3                      Infor
# 4                  JUUL Labs
# 5                        爱彼迎
# 6                        陆金所
# 7                     SpaceX
# 8                     WeWork
# 9                     Stripe
# 10                      微众银行
# 11                      菜鸟网络
# 12                      京东数科
# 13                        快手
# 14                        大疆
# 15                      Grab
# 16                      Hulu
# 17     Palantir Technologies
# 18                  DoorDash
# 19                      比特大陆
# 20                      京东物流
# 21                   Samumed
# 22                    GO-JEK
# 23                     Paytm
# 24                      贝壳找房
# 25                       车好多
# 26                   Coupang
# 27                    平安医保科技
# 28                      Wish
# 29                  Coinbase
#                ...
# 464                      优刻得
# 465                    Udaan
# 466                  Udacity
# 467                      云知声
# 468                      V领地
# 469                     View
# 470                  Vlocity
# 471                Vox Media
# 472                      VTS
# 473                       挖财
# 474                   WalkMe
# 475                    WeLab
# 476                     万能钥匙
# 477                      我买网
# 478                      汇桔网
# 479                  Yanolja
# 480                      要出发
# 481                     越海全球
# 482                     一点资讯
# 483                      易久批
# 484                     壹米滴答
# 485                      洋码头
# 486                      有利网
# 487                     网易有道
# 488                     云鸟科技
# 489              Zeta Global
# 490                    掌门1对1
# 491                       转转
# 492    Zipline International
# 493             ZipRecruiter
# Name: 企业名称, Length: 494, dtype: object

# %%
df[['企业名称','估值（亿人民币）','成立年份']].nsmallest(3,'估值（亿人民币）')
# Out:
#              企业名称  估值（亿人民币）  成立年份
# 263          百融金服        70  2014
# 264  10X Genomics        70  2012
# 265          一起作业        70  2007

# %%
df.iloc[:,[1,2,5]]
# : 的意思是从哪里开始到哪里结束，如果不写的话就是取全部即从头开始到尾巴结束；
# il是按位置取数字
# Out:
#                       企业名称                   Company Name     城市
# 0                     蚂蚁金服                  Ant Financial     杭州
# 1                     字节跳动                      Bytedance     北京
# 2                     滴滴出行                   Didi Chuxing     北京
# 3                    Infor                          Infor     纽约
# 4                JUUL Labs                      JUUL Labs    旧金山
# 5                      爱彼迎                         Airbnb    旧金山
# 6                      陆金所                          Lufax     上海
# 7                   SpaceX                         SpaceX    洛杉矶
# 8                   WeWork                         WeWork     纽约
# 9                   Stripe                         Stripe    旧金山
# 10                    微众银行                         WeBank     深圳
# 11                    菜鸟网络                        Cainiao     杭州
# 12                    京东数科                      JD Digits     北京
# 13                      快手                       Kuaishou     北京
# 14                      大疆                            DJI     深圳
# 15                    Grab                           Grab    新加坡
# 16                    Hulu                           Hulu    洛杉矶
# 17   Palantir Technologies          Palantir Technologies  帕洛阿尔托
# 18                DoorDash                       DoorDash    旧金山
# 19                    比特大陆                        Bitmain     北京
# 20                    京东物流                   JD Logistics     北京
# 21                 Samumed                        Samumed   圣地亚哥
# 22                  GO-JEK                         GO-JEK    雅加达
# 23                   Paytm                          Paytm    诺伊达
# 24                    贝壳找房                          Beike     天津
# 25                     车好多                           CARS     北京
# 26                 Coupang                        Coupang     首尔
# 27                  平安医保科技  Ping An Healthcare Technology     上海
# 28                    Wish                           Wish    旧金山
# 29                Coinbase                       Coinbase    旧金山
# ..                     ...                            ...    ...
# 464                    优刻得                         UCloud     上海
# 465                  Udaan                          Udaan   班加罗尔
# 466                Udacity                        Udacity    山景城
# 467                    云知声                       Unisound     北京
# 468                    V领地                       V Linker     上海
# 469                   View                           View    苗必达
# 470                Vlocity                        Vlocity    旧金山
# 471              Vox Media                      Vox Media    华盛顿
# 472                    VTS                            VTS     纽约
# 473                     挖财                          Wacai     杭州
# 474                 WalkMe                         WalkMe    旧金山
# 475                  WeLab                          WeLab     香港
# 476                   万能钥匙                WiFi Master key     上海
# 477                    我买网                          Womai     北京
# 478                    汇桔网                          WTOIP     广州
# 479                Yanolja                        Yanolja     首尔
# 480                    要出发                       Yaochufa     广州
# 481                   越海全球                      YH Global     深圳
# 482                   一点资讯                    Yidianzixun     北京
# 483                    易久批                        Yijiupi     北京
# 484                   壹米滴答                       Yimidida     上海
# 485                    洋码头                         yMatou     上海
# 486                    有利网                          Yooli     北京
# 487                   网易有道                         Youdao     北京
# 488                   云鸟科技                        Yunniao     北京
# 489            Zeta Global                    Zeta Global     纽约
# 490                  掌门1对1                       Zhangmen     上海
# 491                     转转                     Zhuanzhuan     北京
# 492  Zipline International          Zipline International    半月湾
# 493           ZipRecruiter                   ZipRecruiter    洛杉矶
#
# [494 rows x 3 columns]

# %% [markdown]
# ![03_subset_columns_rows.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/03_subset_columns_rows.svg)
# ### 切切切的小结
# <div class="emoticon">😃😄😁</div>
#
# 1. 揉捏数据， 行跟列可以串接，前提是跑出来的数据要用数据框（先行再列）
# 2. 列子集为取观察；
# 3. 行子集为取变数＋排列
#
#
# -----
# -----

# %% [markdown]
# ![04_plot_overview.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/04_plot_overview.svg)
# ## 如何在熊猫中绘图？
#
# > <mark>绘绘绘</mark>，**绘图** ( 数据框.plot() ) 是数据科学家**以数据框为中心**的代码实践，减少以图表类型为开头的编程思维来作图

# %% [markdown]
# ### 绘绘绘的代码片语
# 绘绘绘的代码片语 (code snippets)，新手请认真记忆，**注意标点及缩进**
#
# ```python
# df.plot()
# ```
#
# 代码片语说明
#
# -----

# %%
df[["估值（亿人民币）"]].plot(kind="bar")

# %%
# %matplotlib inline
import matplotlib as mpl  
mpl.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签  
mpl.rcParams['axes.unicode_minus']=False #用来正常显示负号 

df.loc[[0,1,2,3,4,5],["估值（亿人民币）"]].plot(kind="bar")

# %% [markdown]
# ![04_plot_overview.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/04_plot_overview.svg)
# ### 绘绘绘的小结
#
# 1. df.plot()
#
#
# <div class="emoticon">😃😄😁</div>
#
# -----
# -----

# %% [markdown]
# ![05_newcolumn_2.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/05_newcolumn_2.svg)
# ## 如何从现有列创建派生新列？
# > <mark>列列列</mark>，派生新列意谓着变数variables的进一部转换，是数据科学家按步就班做ETL的过程，新派生列就是**变数variables**的转换

# %% [markdown]
# ### 列列列的代码片语
# 列列列的代码片语 (code snippets)，新手请认真记忆，**注意标点及缩进**
#
# ```python
#
# df['新变量'] = df['变量X'] + df['变量Y']
# df['新变量'] = [ 转换(x) for x in df['变量Y'] ]     # 列表推导转换
#
# ```
#
# 代码片语说明
#
# -----

# %% [markdown]
# ![05_newcolumn_2.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/05_newcolumn_2.svg)
#
# <div class="emoticon">😃😄😁</div>
#
# -----
# -----

# %% [markdown]
# ![06_groupby.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/06_groupby.svg)
#
# ## 如何计算汇总描述性统计信息？
# 算算算，描述性统计竟然代码可以这麽容易....，但难的仍是在数据科学家的数据定义及解释上

# %% [markdown]
# ### 算算算的代码片语
# 算算算的代码片语 (code snippets)，新手请认真记忆，**注意标点及缩进**
#
# ```python
#
# df.describe()
# df.describe(include=all)
#
# df.count()
# df.sum()
#
# df.min()
# df.max()
# df.mean()
# df.median()
#
# df.var()
# df.std()
# ```
#
# 代码片语说明
#
# -----

# %% [markdown]
# ![06_groupby.svg](https://pandas.pydata.org/pandas-docs/version/1.0.2/_images/06_groupby.svg)
